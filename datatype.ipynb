# %%
print("harneet")
# Out:
# harneet

# %%
print(4)
# Out:
# 4

# %%
print(False) #boolean
# Out:
# False

# %%
print(8.0)
# Out:
# 8.0

# %%
print("jdss","kdn","dde") # string
# Out:
# jdss kdn dde

# %%
print("jdss","kdn","dde", sep='/')
# Out:
# jdss/kdn/dde

# %%
print("Hello", end='')
print("World")
# Out:
# HelloWorld

# %%
print(4,5.0) #int, float
# Out:
# 4 5.0

# %%
print([1,2,3])# list
print({1,2,3,4})
print((2,3,4))
# Out:
# [1, 2, 3]
# {1, 2, 3, 4}
# (2, 3, 4)

# %%
#enhance readability 
#comments
