# %%
# C long 
# int a=5
# in python no need to declare variable

# %%
name = "Harneet"

# %%
print(name)
# Out:
# Harneet

# %%
# two types of variable 
# dynamic 
# static
# dynamic variable 
a=5;b=4;c=8
print(a,b,c)
# Out:
# 5 4 8

# %%
a,b,c=2,3,4
print(a,b,c)
# Out:
# 2 3 4

# %%
# keywords : lower case != uppercase
import keyword
print(keyword.kwlist)
# Out:
# ['False', 'None', 'True', 'and', 'as', 'assert', 'async', 'await', 'break', 'class', 'continue', 'def', 'del', 'elif', 'else', 'except', 'finally', 'for', 'from', 'global', 'if', 'import', 'in', 'is', 'lambda', 'nonlocal', 'not', 'or', 'pass', 'raise', 'return', 'try', 'while', 'with', 'yield']

# %%
# Identifier is name used to identify a variable, function, class, module or the the object.

# %%
input("Enter name")
# Out:
# Enter name harneet
# 'harneet'

# %%
# input from user adding two numbers
first_num = int(input("Enter the first number"))
sec_num = int(input("ENter the second number"))
print("first number: ",first_num)
print("second number: ",sec_num)
result = first_num + sec_num
print("Total is: ",result)
# Out:
# Enter the first number 3
# ENter the second number 4
# first number:  3
# second number:  4
# Total is:  7

# %%
# type 
type(4)
# Out:
# int

# %%
#implicit: python automatically converts the data type 
4 + 5.5
# explicit: programmer need to tell the system about conversion
# Out:
# 9.5
